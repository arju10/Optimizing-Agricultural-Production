# %%
#import libraries
# Manipulations
import numpy as np # Complex Mathmetical Problem / Linear Algebra
import pandas as pd # Dataframe Manipulation   / Data Processing

# Data Visualization
import seaborn as sns # Data Visualization
import matplotlib.pyplot as plt # Data Visualization

# Interactive
import ipywidgets  #interactive analysis (interact with python help by ipywidgets)
from ipywidgets import interact

# 
import sklearn  # Implement Machine Learning Model

# %%
# Load Dataset
data = pd.read_csv("E:\\Data Science Projects\\Datas\\agricultural_production.csv")

# %%
# Check Data Shape
print("Data Shape : ",data.shape)
# Out:
# Data Shape :  (2200, 8)

# %%
# Show first 5 rows 
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Find Missing Values on Columns and rows
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# In this dataset>>> NO missing values.
#
#
# If There is any missing values , then we handle them some ways >>>>
# - Fill-NA function is used to replace these missing values with satistical values such as Mean, Mediun, Mode
# - NA means Not Available
# - Pandas have function like fill-NA, drop-NA to treat missing values

# %% [markdown]
# Q. When We use mean, mediun and mode for hanlde missing values ?
# Use of Mean , Mediun and Mode
# - Numerical Column >>> Mean
# - A lot of Out layers >>> Mediun
# - Categorical Column >>> Mode

# %%
# Check the Crops present in this dataset
data['label'].value_counts()   # value_counts() >>> Find the unique values in catagorical column (How Much unique values are present in "label" Column)
# Out:
# chickpea       100
# mango          100
# pomegranate    100
# jute           100
# lentil         100
# maize          100
# kidneybeans    100
# apple          100
# mothbeans      100
# orange         100
# coffee         100
# blackgram      100
# mungbean       100
# rice           100
# papaya         100
# banana         100
# watermelon     100
# pigeonpeas     100
# grapes         100
# muskmelon      100
# coconut        100
# cotton         100
# Name: label, dtype: int64

# %%
# Summery for all the crops

print("Average Ratio of Nitrogen in the soil : {0:.2f}".format(data['N'].mean()))
print("Average Ratio of Phosphorus in the soil : {0:.2f}".format(data['P'].mean()))
print("Average Ratio of Potassium in the soil : {0:.2f}".format(data['K'].mean()))
print("Average Temperature in Celcius: {0:.2f}".format(data['temperature'].mean()))
print("Average Relative Humidity in % : {0:.2f}".format(data['humidity'].mean()))
print("Average PH value of the soil : {0:.2f}".format(data['ph'].mean()))
print("Average Rainfall in mm : {0:.2f}".format(data['rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the soil : 50.55
# Average Ratio of Phosphorus in the soil : 53.36
# Average Ratio of Potassium in the soil : 48.15
# Average Temperature in Celcius: 25.62
# Average Relative Humidity in % : 71.48
# Average PH value of the soil : 6.47
# Average Rainfall in mm : 103.46

# %%
# Check the summary Satistics for each of the crops
# crops = list(data['label'].value_counts().index)
@interact
def summary(crops = list(data['label'].value_counts().index)):
    x = data[data['label'] == crops]
    
    print("..........................................")
    print("Statistics for Nitrogen")
    print("Minimum Nitrogen required : ",x['N'].min())
    print("Maximum Nitrogen required : ",x['N'].max())
    print("Average Nitrogen required : ",x['N'].mean())
    
    print("..........................................")
    print("Statistics for Phosphorus")
    print("Minimum Phosphorus required : ",x['P'].min())
    print("Maximum Phosphorus required : ",x['P'].max())
    print("Average Phosphorus required : ",x['P'].mean())
    
    print("..........................................")
    print("Statistics for Potassium")
    print("Minimum Potassium required : ",x['K'].min())
    print("Maximum Potassium required : ",x['K'].max())
    print("Average Potassium required : ",x['K'].mean())
    
    print("..........................................")
    print("Statistics for Temperature")
    print("Minimum Temperature required : ",x['temperature'].min())
    print("Maximum Temperature required : ",x['temperature'].max())
    print("Average Temperature required : ",x['temperature'].mean())
    
    print("..........................................")
    print("Statistics for Humidity")
    print("Minimum Humidity required : ",x['humidity'].min())
    print("Maximum Humidity required : ",x['humidity'].max())
    print("Average Humidity required : ",x['humidity'].mean())
    
    print("..........................................")
    print("Statistics for PH")
    print("Minimum PH required : ",x['ph'].min())
    print("Maximum PH required : ",x['ph'].max())
    print("Average PH required : ",x['ph'].mean())
    
    print("..........................................")
    print("Statistics for Rainfall")
    print("Minimum Rainfall required : ",x['rainfall'].min())
    print("Maximum Rainfall required : ",x['rainfall'].max())
    print("Average Rainfall required : ",x['rainfall'].mean())
# Out:
# interactive(children=(Dropdown(description='crops', options=('chickpea', 'mango', 'pomegranate', 'jute', 'lent…

# %%
# Compare the average Requirment for each crops with average condition

@interact
def compare(conditions = ["N","P","K","temperature","humidity","ph","rainfall"]):
    print("Average value for",conditions,"is {0:.2f}".format(data[conditions].mean()))
    print("...........................................")
    print("Pomegranate: {0:.2f}".format(data[(data["label"] == 'pomegranate')][conditions].mean()))
    print("Chickpea: {0:.2f}".format(data[(data["label"] == 'chickpea')][conditions].mean()))    
    print("Apple: {0:.2f}".format(data[(data["label"] == 'apple')][conditions].mean()))    
    print("Kidneybeans: {0:.2f}".format(data[(data["label"] == 'kidneybeans')][conditions].mean()))    
    print("Blackgram: {0:.2f}".format(data[(data["label"] == 'blackgram')][conditions].mean()))    
    print("Coffee: {0:.2f}".format(data[(data["label"] == 'coffee')][conditions].mean()))    
    print("Jute: {0:.2f}".format(data[(data["label"] == 'jute')][conditions].mean()))    
    print("Muskmelon: {0:.2f}".format(data[(data["label"] == 'muskmelon')][conditions].mean()))    
    print("Mothbeans: {0:.2f}".format(data[(data["label"] == 'mothbeans')][conditions].mean()))    
    print("Banana: {0:.2f}".format(data[(data["label"] == 'banana')][conditions].mean()))    
    print("Watermelon: {0:.2f}".format(data[(data["label"] == 'watermelon')][conditions].mean()))    
    print("Lentil: {0:.2f}".format(data[(data["label"] == 'lentil')][conditions].mean()))    
    print("Papaya: {0:.2f}".format(data[(data["label"] == 'papaya')][conditions].mean()))
    print("Mungbean: {0:.2f}".format(data[(data["label"] == 'mungbean')][conditions].mean()))       
    print("Rice: {0:.2f}".format(data[(data["label"] == 'rice')][conditions].mean()))       
    print("Coconut: {0:.2f}".format(data[(data["label"] == 'coconut')][conditions].mean()))       
    print("Cotton: {0:.2f}".format(data[(data["label"] == 'cotton')][conditions].mean()))
    print("Mango: {0:.2f}".format(data[(data["label"] == 'mango')][conditions].mean()))         
    print("Grapes: {0:.2f}".format(data[(data["label"] == 'grapes')][conditions].mean()))         
    print("Orange: {0:.2f}".format(data[(data["label"] == 'orange')][conditions].mean()))         
    print("Maize: {0:.2f}".format(data[(data["label"] == 'maize')][conditions].mean()))         
    print("Pigeonpeas: {0:.2f}".format(data[(data["label"] == 'pigeonpeas')][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'humidity', 'p…

# %%
#

@interact
def compare(conditions = ["N","P","K","temperature","humidity","ph","rainfall"]):
    print("Crops which require greater than average : ",conditions,"\n")
    print(data[data[conditions] > data[conditions].mean()]['label'].unique())
    print("\n>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>\n")
    print("Crops which require less than average : ",conditions,"\n")
    print(data[data[conditions] < data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'humidity', 'p…

# %% [markdown]
# # Distribution of Agricultural Condition

# %%
plt.figure(figsize=(25,16))

plt.subplot(2,4,1)
sns.distplot(data["N"], color = "red")
plt.xlabel("Ratio of Nitrogen", fontsize = 12)

plt.subplot(2,4,2)
sns.distplot(data["P"], color = "green")
plt.xlabel("Ratio of Phosphorus", fontsize = 12)

plt.subplot(2,4,3)
sns.distplot(data["K"], color = "black")
plt.xlabel("Ratio of Potassium", fontsize = 12)

plt.subplot(2,4,4)
sns.distplot(data["temperature"], color = "gray")
plt.xlabel("Ratio of Temperature", fontsize = 12)

plt.subplot(2,4,5)
sns.distplot(data["ph"], color = "yellow")
plt.xlabel("Ratio of PH", fontsize = 12)

plt.subplot(2,4,6)
sns.distplot(data["rainfall"], color = "blue")
plt.xlabel("Ratio of Rainfall", fontsize = 12)

plt.subplot(2,4,7)
sns.distplot(data["humidity"], color = "orange")
plt.xlabel("Ratio of Humidity", fontsize = 12)

plt.subplot(2,4,8)
sns.distplot(data["rainfall"], color = "red")
plt.xlabel("Ratio of Rainfall", fontsize = 12)

plt.suptitle("Distribution of Agricultural Conditions", fontsize= 24)
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Find out some interesting facts

print("Some intertesting Patterns")
print("............................")
print("Crops which requires very High Ratio of Nitrogen Content in Soil",data[data["N"] > 120]["label"].unique())
print("Crops which requires very High Ratio of Phosphorus Content in Soil",data[data["P"] > 100]["label"].unique())
print("Crops which requires very High Ratio of Potassium Content in Soil",data[data["K"] > 200]["label"].unique())
print("Crops which requires very High Rainfall ",data[data["rainfall"] > 200]["label"].unique())
print("Crops which requires very High Temperature",data[data["temperature"] > 40]["label"].unique())
print("Crops which requires very Low Temperature",data[data["temperature"] < 10]["label"].unique())
print("Crops which requires very Low Humidity",data[data["humidity"] > 20]["label"].unique())
print("Crops which requires very Low PH",data[data["ph"] < 4]["label"].unique())
print("Crops which requires very High Low PH",data[data["ph"] > 9]["label"].unique())
# Out:
# Some intertesting Patterns
# ............................
# Crops which requires very High Ratio of Nitrogen Content in Soil ['cotton']
# Crops which requires very High Ratio of Phosphorus Content in Soil ['grapes' 'apple']
# Crops which requires very High Ratio of Potassium Content in Soil ['grapes' 'apple']
# Crops which requires very High Rainfall  ['rice' 'papaya' 'coconut']
# Crops which requires very High Temperature ['grapes' 'papaya']
# Crops which requires very Low Temperature ['grapes']
# Crops which requires very Low Humidity ['rice' 'maize' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes' 'watermelon'
#  'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton' 'jute' 'coffee']
# Crops which requires very Low PH ['mothbeans']
# Crops which requires very High Low PH ['mothbeans']

# %%
# Which crops can only be Grown in Summer , Winter and Rainy Season

print("Summer Season")
print(data[(data["temperature"] > 30) & (data["humidity"] > 50)]["label"].unique())
print("..........................................................")
print("Winter Season")
print(data[(data["temperature"] < 20) & (data["humidity"] > 30)]["label"].unique())
print("..........................................................")
print("Rainy Season")
print(data[(data["rainfall"] > 200) & (data["humidity"] > 30)]["label"].unique())
# Out:
# Summer Season
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# ..........................................................
# Winter Season
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# ..........................................................
# Rainy Season
# ['rice' 'papaya' 'coconut']

# %%
from sklearn.cluster import KMeans

# Remove the Labels Column
x = data.drop(['label'], axis=1)

# Selecting all the values of the data
x = x.values

#Check the shape
print(x.shape)
# Out:
# (2200, 7)

# %%
# Determine the optimum number of Cluster within the Dataset

plt.rcParams['figure.figsize'] = (10, 4)

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters= i, init= "k-means++", max_iter= 300, n_init= 10, random_state= 0)
    km.fit(x)
    wcss.append(km.inertia_)
    

    
# Plot The Result
plt.plot(range(1, 11),wcss)
plt.title("The Elbow Method", fontsize = 20)
plt.xlabel("No. of Cluster")
plt.ylabel("wcss")
plt.show()

# %%
# implement the K Means algorithm to perform Clustering analysis
km = KMeans(n_clusters=4, init= "k-means++", max_iter= 300, n_init=10, random_state= 0)
y_means = km.fit_predict(x)

#Find out the Results
a = data['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis= 1)
z = z.rename(columns = {0: 'cluster'})

# Check the Clusters of each Crops
print("Check the Results After Applying K Means Clustering Analysis \n")
print("Crops in first cluster: ", z[z['cluster'] == 0]['label'].unique())
print("................................................................")
print("Crops in Second cluster: ", z[z['cluster'] == 1]['label'].unique())
print("................................................................")
print("Crops in Third cluster: ", z[z['cluster'] == 2]['label'].unique())
print("................................................................")
print("Crops in Forth cluster: ", z[z['cluster'] == 3]['label'].unique())
# Out:
# Check the Results After Applying K Means Clustering Analysis
#
# Crops in first cluster:  ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']
# ................................................................
# Crops in Second cluster:  ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ................................................................
# Crops in Third cluster:  ['grapes' 'apple']
# ................................................................
# Crops in Forth cluster:  ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']

# %%
# Split the Dataset for Predictive Modeling

y = data['label']
x = data.drop(['label'], axis = 1)

print("Shape of x : ",x.shape)
print("Shape of y : ",y.shape)
# Out:
# Shape of x :  (2200, 7)
# Shape of y :  (2200,)

# %%
# Create Training and Tesing Sets for Validation of Results
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print("The Shape of x train : ",x_train.shape)
print("The Shape of x test : ",x_test.shape)
print("The Shape of y train : ",y_test.shape)
print("The Shape of y test : ",y_test.shape)
# Out:
# The Shape of x train :  (1760, 7)
# The Shape of x test :  (440, 7)
# The Shape of y train :  (440,)
# The Shape of y test :  (440,)

# %%
# Create a Prediction Model

from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='saga',max_iter=7200)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
# Evaluate the Model Performance
from sklearn.metrics import confusion_matrix

#Print the Confusion matrix first
plt.rcParams['figure.figsize'] = (10,10)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot= True, cmap = 'Wistia')
plt.title("Confusion Matrix for Logistric Regression")
plt.show()

# %%
# Print the Classification Report also
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.79      0.86      0.83        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.88      0.94      0.91        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.87      0.95      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       1.00      0.94      0.97        17
#        maize       0.89      0.89      0.89        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.84      0.86        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
# Check the Head of the Dataset
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction = model.predict((np.array([[90,40,40,20,80,7,200]])))
print("The suggested Crop for Given Climatic Condition is  :",prediction)
# Out:
# The suggested Crop for Given Climatic Condition is  : ['rice']
